# %%
print("Digite seu nome: ")
nome = input()

executar = True

while(executar == True):
  print("Digite seu ano de nascimento: ")
  try:
    ano = int(inpu())

    if(ano < 1922) or (ano > 2021):
      print("O ano precisa ser entre 1922 e 2021")
    else:
      idade = 2022 - ano
      print("O usuário", nome, "completou ou completará", idade, "anos de idade")
      executar = False
  except:
    print("Os ano devem ser escritos apenas com números")
